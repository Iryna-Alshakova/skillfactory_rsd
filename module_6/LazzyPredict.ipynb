# %%
import lazypredict
import pandas as pd

# %%
data = pd.read_csv('all_data.csv')

# %%
data.sample(10)
# Out:
#        Unnamed: 0  enginePower  mileage  productionDate     sell_id  vendor  \
# 37864       37864         4.13     0.32           -0.02  1097229170       1
# 24627       24627        -0.22    -0.01            0.12  1097465298       1
# 32219       32219        -0.49    -0.58            0.98  1101316654       0
# 36834       36834         0.01    -1.52            1.40  1102573551       1
# 52669       52670         1.25     0.76           -1.01  1101908529       1
# 11009       11009         2.95    -0.83            0.69  1100400226       1
# 25611       25611        -1.29     2.03           -1.58  1098572108       1
# 71278       71279         1.42    -0.09           -0.30  1102505306       0
# 44582       44582        -0.91    -0.22            0.12  1102729535       0
# 20157       20157        -0.56     0.50           -2.00  1101252318       0
#
#        Владельцы  ПТС  Руль  sample  ...  numberOfDoors_5  \
# 37864          3    0     1       1  ...                1
# ...

# %%
data.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
y = data[data['sample']==1]['price']
X = data.query('sample == 1').drop(['sample', 'price'], axis=1)
X_sub = data.query('sample == 0').drop(['sample', 'price'], axis=1)

# %%
from sklearn.model_selection import train_test_split
RANDOM_SEED = 42
VAL_SIZE   = 0.20   # 20%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=VAL_SIZE, shuffle=True, random_state=RANDOM_SEED)

# %%
from lazypredict.Supervised import LazyClassifier, LazyRegressor
import sklearn.utils.testing
reg = LazyRegressor(verbose=0, ignore_warnings=True, custom_metric=None, predictions=True)
models, predictions = reg.fit(X_train, X_test, y_train, y_test)
print(models)
# Out:
# 100%|██████████| 42/42 [41:09<00:00, 58.80s/it]
#                                Adjusted R-Squared     R-Squared  \
# Model
# ExtraTreesRegressor                          0.94          0.94
# LGBMRegressor                                0.94          0.94
# XGBRegressor                                 0.94          0.94
# RandomForestRegressor                        0.94          0.94
# HistGradientBoostingRegressor                0.93          0.93
# BaggingRegressor                             0.93          0.93
# GradientBoostingRegressor                    0.93          0.93
# DecisionTreeRegressor                        0.88          0.88
# ExtraTreeRegressor                           0.87          0.87
# PoissonRegressor                             0.84          0.84
# KNeighborsRegressor                          0.84          0.84
# GammaRegressor                               0.66          0.67
# BayesianRidge                                0.63          0.64
# ...

# %%
models.to_csv('models_lazzy_2.csv')

# %%
model=pd.read_csv('models_lazzy_2.csv')

# %%
model
# Out:
#                             Model  Adjusted R-Squared     R-Squared  \
# 0             ExtraTreesRegressor                0.94          0.94
# 1                   LGBMRegressor                0.94          0.94
# 2                    XGBRegressor                0.94          0.94
# 3           RandomForestRegressor                0.94          0.94
# 4   HistGradientBoostingRegressor                0.93          0.93
# 5                BaggingRegressor                0.93          0.93
# 6       GradientBoostingRegressor                0.93          0.93
# 7           DecisionTreeRegressor                0.88          0.88
# 8              ExtraTreeRegressor                0.87          0.87
# 9                PoissonRegressor                0.84          0.84
# 10            KNeighborsRegressor                0.84          0.84
# 11                 GammaRegressor                0.66          0.67
# 12                  BayesianRidge                0.63          0.64
# ...
